# %% [markdown]
# ## SpmImages.jl Demo

# %%
using SpmImages
using Plots  # needs to be manually imported for plotting functions

# %% [markdown]
# ### Load SPM image

# %%
ima = load_image("Image_445.sxm");

# %% [markdown]
# ## Plot a specific image channel directly from the image

# %%
plot_channel(ima, "frequency shift")

# %% [markdown]
# ### Get a channel as 2D data and directly plot it

# %%
c = get_channel(ima, "current");
plot_data(c.data, color=:lapaz, title="current", legend=:none)

# %% [markdown]
# ### Plot using the Images library

# %%
using Images
d = get_channel(ima, "current bwd", origin="upper").data
d = d .- minimum(d)
d = d ./ maximum(d)
Gray.(d)
# Out:
# 192×96 Array{Gray{Float32},2} with eltype Gray{Float32}:
#  Gray{Float32}(0.0700887)  …  Gray{Float32}(0.00401743)
#  Gray{Float32}(0.0650853)     Gray{Float32}(0.00349568)
#  Gray{Float32}(0.057221)      Gray{Float32}(0.00505849)
#  Gray{Float32}(0.0463883)     Gray{Float32}(0.00581613)
#  Gray{Float32}(0.035832)      Gray{Float32}(0.00557018)
#  Gray{Float32}(0.0301628)  …  Gray{Float32}(0.00520382)
#  Gray{Float32}(0.0278184)     Gray{Float32}(0.00424598)
#  Gray{Float32}(0.0261225)     Gray{Float32}(0.00508224)
#  Gray{Float32}(0.0252468)     Gray{Float32}(0.00548286)
#  Gray{Float32}(0.0223281)     Gray{Float32}(0.00522088)
#  Gray{Float32}(0.0212512)  …  Gray{Float32}(0.00619607)
#  Gray{Float32}(0.0160234)     Gray{Float32}(0.00646253)
#  Gray{Float32}(0.0186728)     Gray{Float32}(0.0070657)
#  ⋮                         ⋱  ⋮
#  Gray{Float32}(0.0163371)  …  Gray{Float32}(0.00313412)
#  Gray{Float32}(0.0134273)     Gray{Float32}(0.00370309)
#  Gray{Float32}(0.0140006)     Gray{Float32}(0.00420697)
#  Gray{Float32}(0.0141547)     Gray{Float32}(0.00374715)
#  Gray{Float32}(0.0148523)     Gray{Float32}(0.00414591)
#  Gray{Float32}(0.0127841)  …  Gray{Float32}(0.00376427)
#  Gray{Float32}(0.015415)      Gray{Float32}(0.00287433)
#  Gray{Float32}(0.0147834)     Gray{Float32}(0.00232915)
#  Gray{Float32}(0.0134008)     Gray{Float32}(0.00173998)
#  Gray{Float32}(0.0134846)     Gray{Float32}(0.0017709)
#  Gray{Float32}(0.0140214)  …  Gray{Float32}(0.00135037)
#  Gray{Float32}(0.012934)      Gray{Float32}(0.000718081)
